# %%
#import libraries to connect SQL db
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
conn = pymysql.connect(host= 'comphcitwo.eecs.umich.edu', user = 'behavior_model_user', password = '1)wfCiyBMU', db = 'behavior_model')
cursor = conn.cursor()  #create a cursor This will allow us to execute the SQL query once we’ve written it

# %%
Study_ID = 179 #latest MS model study_id
run_id = 58 #
population_id = 206 #will be needed to see what are the actual states and actions of MS patients
fold_id = 57 #concerns about theta

# %%
Fold_State_Counts_sql = """select expected_count from Fold_State_Counts where state_id = %s
"""

# %%
State_Action_Policy_sql = """ select probability from State_Action_Policy where state_id = %s and action_id = %s;
"""

# %%
State_Transition_sql = """ select probability from State_Transition where from_state_id = %s and action_id = %s;
"""

# %%
to_state_sql = """ select to_state_id from State_Transition where from_state_id = %s and action_id = %s;
"""

# %%
get_state_code_sql = """ select state_code from State where id = %s;
"""

# %% [markdown]
# ### Map State features to State code

# %%
#State features
GENDER = ["Male", "Female"] #Dem_02
AGE = ["Younger than 30", "Between 30 to 60", "60 and Older"] #Dem_01
DAYTIME_INTERVAL = ["Wake", "Morning", "Afternoon", "Evening", "Bed"] #Morning: 11am, Afternoon: 3pm, Evening: 7pm
## Lower: below 33th percentile; Normal: 33rd to 66th percentile; Higher: Above 66th percentile
PAIN = ["Lower", "Normal", "Higher", "Not Recorded"] 
FATIGUE = ["Lower", "Normal", "Higher", "Not Recorded"]
LAST_ACTIVITYBOUTS = ["Lower", "Normal", "Higher", "Not Recorded"]
EOD_PAW = ["Lower", "Normal", "Higher", "Not Recorded", None] #depends on prev action #positive affect and well-being (PAWB) higher scores indicated higher PAWB
## EOD_PAW is only recorded in the bed state, otherwise it is None.

# %%
states = {}
state_name_index = 1
import itertools
for x in itertools.product(GENDER, AGE, DAYTIME_INTERVAL, PAIN, FATIGUE, LAST_ACTIVITYBOUTS, EOD_PAW):
    if(not(x[2] == "Bed") and not(x[6] == None)):
        continue
    if(x[2] == "Bed" and x[6] == None):
        continue
    state = {}
    state["Gender"] = x[0]
    state["Age"] = x[1]
    state["Current Daytime Interval"] = x[2]
    state["Current Interval Pain Score"] = x[3]
    state["Current Interval Fatigue Score"] = x[4]
    state["Last Interval Activity Bouts"] = x[5]
    state["EOD Positive Affect and Well-being"] = x[6]
    state_code = 'S' + str(state_name_index)
    states[state_code] = state
    state_name_index += 1

# %%
len(states)
# Out:
# 3072

# %%
states["S100"]
# Out:
# {'Gender': 'Male',
#  'Age': 'Younger than 30',
#  'Current Daytime Interval': 'Morning',
#  'Current Interval Pain Score': 'Higher',
#  'Current Interval Fatigue Score': 'Lower',
#  'Last Interval Activity Bouts': 'Not Recorded',
#  'EOD Positive Affect and Well-being': None}

# %% [markdown]
# ### Map Action features to Action Code

# %%
#Action 
ACTIVITYBOUTS = ["Lower", "Normal", "Higher", "Not Recorded"] #what actions have been taken in current state (this action will decide the transition to next state)
DAILY_INTERVAL_ASSESSMENT_PAIN = ["Recorded", "Not Recorded"] #what will be the pain in next state
DAILY_INTERVAL_ASSESSMENT_FATIGUE = ["Recorded", "Not Recorded"] # what will be the fatigue in next state
DAILY_INTERVAL_ASSESSMENT_PAW = ["Recorded", "Not Recorded", None] #what will be the positive affect and well-being in next state
#PAW is only recorded in the bed state, otherwise it is None. As Action decides next state, 
#DAILY_INTERVAL_ASSESSMENT_PAW action will be None in the Evening action case, which will ensure PAW = None in the bed state

# %%
actions = {}
action_name_index = 1
for x in itertools.product(ACTIVITYBOUTS, DAILY_INTERVAL_ASSESSMENT_PAIN, DAILY_INTERVAL_ASSESSMENT_FATIGUE, DAILY_INTERVAL_ASSESSMENT_PAW):
    action = {}
    action["Activitybouts"] = x[0]
    action["Next Interval Assessment Pain"] = x[1]
    action["Next Interval Assessment Fatigue"] = x[2]
    action["Next Interval Assessment PAW"] = x[3]
    
    action_code = 'A' + str(action_name_index)
    actions[action_code] = action
    action_name_index += 1

# %%
len(actions)
# Out:
# 48

# %%
actions["A1"]
# Out:
# {'Activitybouts': 'Lower',
#  'Next Interval Assessment Pain': 'Recorded',
#  'Next Interval Assessment Fatigue': 'Recorded',
#  'Next Interval Assessment PAW': 'Recorded'}

# %%
Action_list = list(actions.keys()) #All Actions

# %%
#Evening action list (Actions that can be done only in the Evening states)
Evening_action_list = [key for key, items in actions.items() if items['Next Interval Assessment PAW'] != None]
Evening_action_list
# Out:
# ['A1',
#  'A2',
#  'A4',
#  'A5',
#  'A7',
#  'A8',
#  'A10',
#  'A11',
#  'A13',
#  'A14',
#  'A16',
#  'A17',
#  'A19',
#  'A20',
#  'A22',
#  'A23',
#  'A25',
#  'A26',
#  'A28',
#  'A29',
#  'A31',
#  'A32',
#  'A34',
#  'A35',
#  'A37',
#  'A38',
#  'A40',
#  'A41',
#  'A43',
#  'A44',
#  'A46',
#  'A47']

# %%
# Actions that can be done in Wake, Morning, Afternoon, Bed 
WMAB_action_list = [key for key, items in actions.items() if items['Next Interval Assessment PAW'] == None]
WMAB_action_list
# Out:
# ['A3',
#  'A6',
#  'A9',
#  'A12',
#  'A15',
#  'A18',
#  'A21',
#  'A24',
#  'A27',
#  'A30',
#  'A33',
#  'A36',
#  'A39',
#  'A42',
#  'A45',
#  'A48']

# %% [markdown]
# ### All Necessary functions

# %%
def state_to_state_code(state):
    #input: state
    #output: state_code
    return list(states.keys())[list(states.values()).index(state)]

# %%
def action_to_action_code(action):
    #input: action
    #output: action_code
    return list(actions.keys())[list(actions.values()).index(action)]

# %% [markdown]
# ### Understanding SQL Tables

# %% [markdown]
# ### State (id, state-code, feature_count, study_id)  where, id = state_id

# %%
State_sql = """ SELECT * from State WHERE study_id = 179;
"""
State_sql_df = pd.read_sql(State_sql, conn)

# %%
State_sql_df ## see the query at the top
# Out:
#            id state_code  feature_count  study_id
# 0     3315187         S1             26       179
# 1     3315188         S2             26       179
# 2     3315189         S3             26       179
# 3     3315190         S4             26       179
# 4     3315191         S5             26       179
# ...       ...        ...            ...       ...
# 3067  3318254      S3068             26       179
# 3068  3318255      S3069             26       179
# 3069  3318256      S3070             26       179
# 3070  3318257      S3071             26       179
# 3071  3318258      S3072             26       179
#
# [3072 rows x 4 columns]

# %% [markdown]
# ### Action (id, action-code, feature_count, study_id)  where, id = action_id

# %%
Action_sql = """select * from Action where study_id = 179;"""
Action_sql_df = pd.read_sql(Action_sql, conn)

# %%
Action_sql_df
# Out:
#       id action_code  feature_count  study_id
# 0   8971          A1             10       179
# 1   8972          A2             10       179
# 2   8973          A3             10       179
# 3   8974          A4             10       179
# 4   8975          A5             10       179
# 5   8976          A6             10       179
# 6   8977          A7             10       179
# 7   8978          A8             10       179
# 8   8979          A9             10       179
# 9   8980         A10             10       179
# 10  8981         A11             10       179
# 11  8982         A12             10       179
# 12  8983         A13             10       179
# 13  8984         A14             10       179
# 14  8985         A15             10       179
# 15  8986         A16             10       179
# 16  8987         A17             10       179
# 17  8988         A18             10       179
# 18  8989         A19             10       179
# 19  8990         A20             10       179
# 20  8991         A21             10       179
# 21  8992         A22             10       179
# 22  8993         A23             10       179
# 23  8994         A24             10       179
# 24  8995         A25             10       179
# 25  8996         A26             10       179
# 26  8997         A27             10       179
# 27  8998         A28             10       179
# 28  8999         A29             10       179
# 29  9000         A30             10       179
# 30  9001         A31             10       179
# 31  9002         A32             10       179
# 32  9003         A33             10       179
# 33  9004         A34             10       179
# 34  9005         A35             10       179
# 35  9006         A36             10       179
# 36  9007         A37             10       179
# 37  9008         A38             10       179
# 38  9009         A39             10       179
# 39  9010         A40             10       179
# 40  9011         A41             10       179
# 41  9012         A42             10       179
# 42  9013         A43             10       179
# 43  9014         A44             10       179
# 44  9015         A45             10       179
# 45  9016         A46             10       179
# 46  9017         A47             10       179
# 47  9018         A48             10       179

# %% [markdown]
# ### State visitation frequency (D_s)

# %%
# %%latex
# expected frequency of states $D_s$, which estimates how frequently each state occurs in behavior instances in this
# model.
# Table name: Fold_State_Counts
# Out:
# expected frequency of states $D_s$, which estimates how frequently each state occurs in behavior instances in this
# model.
# Table name: Fold_State_Counts

# %%
state_vis_freq_sql = """ select * from Fold_State_Counts as FSC inner join State as S on (FSC.state_id = S.id) where S.study_id = 179; """
state_vis_freq_sql_df = pd.read_sql(state_vis_freq_sql, conn)

# %%
state_vis_freq_sql_df
# Out:
#       fold_id  state_id  expected_count       id state_code  feature_count  \
# 0          57   3315187    4.613333e-03  3315187         S1             26
# 1          57   3315188    4.268798e-03  3315188         S2             26
# 2          57   3315189    4.510243e-03  3315189         S3             26
# 3          57   3315190    2.722751e-04  3315190         S4             26
# 4          57   3315191    7.940638e-03  3315191         S5             26
# ...       ...       ...             ...      ...        ...            ...
# 3067       57   3318254    1.530932e-07  3318254      S3068             26
# 3068       57   3318255    5.282775e-09  3318255      S3069             26
# 3069       57   3318256    8.213010e-09  3318256      S3070             26
# 3070       57   3318257    6.912857e-09  3318257      S3071             26
# 3071       57   3318258    9.922874e-09  3318258      S3072             26
#
#       study_id
# 0          179
# 1          179
# 2          179
# 3          179
# 4          179
# ...        ...
# 3067       179
# 3068       179
# 3069       179
# 3070       179
# 3071       179
#
# [3072 rows x 7 columns]

# %%
states["S5"]
# Out:
# {'Gender': 'Male',
#  'Age': 'Younger than 30',
#  'Current Daytime Interval': 'Wake',
#  'Current Interval Pain Score': 'Lower',
#  'Current Interval Fatigue Score': 'Normal',
#  'Last Interval Activity Bouts': 'Lower',
#  'EOD Positive Affect and Well-being': None}

# %% [markdown]
# ### P(a|s)

# %%
# %%latex
# conditional probability of actions
# given situations $P(a|s)$, which estimates how likely the
# person, with this behavior model, is to perform action $a$ in
# state $s$ in that model.
# here, state_id = from_state_id
# action_id = action that has been performed in from_state
# Out:
# conditional probability of actions
# given situations $P(a|s)$, which estimates how likely the
# person, with this behavior model, is to perform action $a$ in
# state $s$ in that model.
# here, state_id = from_state_id
# action_id = action that has been performed in from_state

# %%
prob_action_given_state_sql = """ select policy_id, state_id, state_code, action_id, action_code, probability from State_Action_Policy as SAP inner join State as S on (SAP.state_id = S.id) inner join Action as A on (SAP.action_id = A.id) where S.study_id = 179 and A.study_id = 179; """

# %%
prob_action_given_state_sql_df = pd.read_sql(prob_action_given_state_sql, conn)

# %%
prob_action_given_state_sql_df
# Out:
#        policy_id  state_id state_code  action_id action_code   probability
# 0             37   3315187         S1       8973          A3  3.400253e-01
# 1             37   3315187         S1       8976          A6  1.034875e-03
# 2             37   3315187         S1       8979          A9  2.803656e-03
# 3             37   3315187         S1       8982         A12  8.369997e-06
# 4             37   3315187         S1       8985         A15  2.695903e-01
# ...          ...       ...        ...        ...         ...           ...
# 55291         37   3318258      S3072       9006         A36  4.588340e-06
# 55292         37   3318258      S3072       9009         A39  1.243086e-02
# 55293         37   3318258      S3072       9012         A42  5.941540e-05
# 55294         37   3318258      S3072       9015         A45  6.665999e-05
# 55295         37   3318258      S3072       9018         A48  3.156127e-07
#
# [55296 rows x 6 columns]

# %% [markdown]
# ### P(s'|s, a)

# %%
# %%latex
# This is called probability of going into state s', if action a is performed in state s.
#
# The probability of the next state after the person performs
# an action in the current state $P(s'|s, a)$ represents how the
# actions that people perform in different situations affect
# their environment and vice-versa.
#
# In our model there are 270336 transitions possible.
# Out:
# This is called probability of going into state s', if action a is performed in state s.
#
# The probability of the next state after the person performs
# an action in the current state $P(s'|s, a)$ represents how the
# actions that people perform in different situations affect
# their environment and vice-versa.
#
# In our model there are 270336 transitions possible.

# %%
transition_proba_sql = """ select ST.from_state_id, S.state_code as from_state_code, action_id, action_code, to_state_id, FS.state_code as to_state_code, probability  from State_Transition as ST inner join State as S on (ST.from_state_id = S.id) inner join Action as A on (ST.action_id = A.id) inner join State as FS on (ST.to_state_id = FS.id) where S.study_id = 179 and A.study_id = 179 and FS.study_id = 179; """

# %%
transition_proba_sql_df = pd.read_sql(transition_proba_sql, conn)

# %%
transition_proba_sql_df
# Out:
#         from_state_id from_state_code  action_id action_code  to_state_id  \
# 0             3315379            S193       8971          A1      3315443
# 1             3315379            S193       8971          A1      3315444
# 2             3315379            S193       8971          A1      3315445
# 3             3315379            S193       8971          A1      3315459
# 4             3315379            S193       8971          A1      3315460
# ...               ...             ...        ...         ...          ...
# 270331        3318254           S3068       9018         A48      3317810
# 270332        3318255           S3069       9018         A48      3317810
# 270333        3318256           S3070       9018         A48      3317810
# 270334        3318257           S3071       9018         A48      3317810
# 270335        3318258           S3072       9018         A48      3317810
#
#        to_state_code  probability
# 0               S257     0.020071
# 1               S258     0.012884
# 2               S259     0.014971
# 3               S273     0.063225
# 4               S274     0.040588
# ...              ...          ...
# 270331         S2624     1.000000
# 270332         S2624     1.000000
# 270333         S2624     1.000000
# 270334         S2624     1.000000
# 270335         S2624     1.000000
#
# [270336 rows x 7 columns]

# %% [markdown]
# ### Theta

# %%
# %%latex
# we assume a parametric reward
# function that is linear in $F_{S, A}$, given unknown weight
# parameters $\theta$:
#     $R(s, a) = \theta^T . F_{s_t, a_t}$
# Out:
# we assume a parametric reward
# function that is linear in $F_{S, A}$, given unknown weight
# parameters $\theta$:
#     $R(s, a) = \theta^T . F_{s_t, a_t}$

# %%
theta_sql = """ select feature_id, feature_name, feature_index, feature_type_id, fold_id, theta  from Fold_Feature_Theta as FFT inner join Feature as F on (FFT.feature_id = F.id) where F.study_id = 179; """

# %%
theta_sql_df = pd.read_sql(theta_sql, conn)

# %%
#feature_type_id = {1:State_feature, 2:Action_feature} #there are 26 state feature and 10 action feature
theta_sql_df
# Out:
#     feature_id                                     feature_name  \
# 0        10634                                      Gender:Male
# 1        10635                                    Gender:Female
# 2        10636                              Age:Younger Than 30
# 3        10637                             Age:Between 30 To 60
# 4        10638                                 Age:60 And Older
# 5        10639                    Current Daytime Interval:Wake
# 6        10640                 Current Daytime Interval:Morning
# 7        10641               Current Daytime Interval:Afternoon
# 8        10642                 Current Daytime Interval:Evening
# 9        10643                     Current Daytime Interval:Bed
# 10       10644                Current Interval Pain Score:Lower
# 11       10645               Current Interval Pain Score:Normal
# 12       10646               Current Interval Pain Score:Higher
# 13       10647         Current Interval Pain Score:Not Recorded
# 14       10648             Current Interval Fatigue Score:Lower
# 15       10649            Current Interval Fatigue Score:Normal
# 16       10650            Current Interval Fatigue Score:Higher
# 17       10651      Current Interval Fatigue Score:Not Recorded
# 18       10652               Last Interval Activity Bouts:Lower
# 19       10653              Last Interval Activity Bouts:Normal
# 20       10654              Last Interval Activity Bouts:Higher
# 21       10655        Last Interval Activity Bouts:Not Recorded
# 22       10656         Eod Positive Affect And Well-Being:Lower
# 23       10657        Eod Positive Affect And Well-Being:Normal
# 24       10658        Eod Positive Affect And Well-Being:Higher
# 25       10659  Eod Positive Affect And Well-Being:Not Recorded
# 26       10660                              Activitybouts:Lower
# 27       10661                             Activitybouts:Normal
# 28       10662                             Activitybouts:Higher
# 29       10663                       Activitybouts:Not Recorded
# 30       10664           Next Interval Assessment Pain:Recorded
# 31       10665       Next Interval Assessment Pain:Not Recorded
# 32       10666        Next Interval Assessment Fatigue:Recorded
# 33       10667    Next Interval Assessment Fatigue:Not Recorded
# 34       10668            Next Interval Assessment Paw:Recorded
# 35       10669        Next Interval Assessment Paw:Not Recorded
#
#     feature_index  feature_type_id  fold_id     theta
# 0               1                1       57  2.435313
# 1               2                1       57  0.679921
# 2               3                1       57  0.056990
# 3               4                1       57  2.666766
# 4               5                1       57  0.056956
# 5               6                1       57  0.223261
# 6               7                1       57  1.482619
# 7               8                1       57  0.066790
# 8               9                1       57  1.004022
# 9              10                1       57  0.445733
# 10             11                1       57  0.325239
# 11             12                1       57  4.965209
# 12             13                1       57  0.007309
# 13             14                1       57  0.526595
# 14             15                1       57  0.502787
# 15             16                1       57  3.929241
# 16             17                1       57  0.919146
# 17             18                1       57  0.904028
# 18             19                1       57  0.795307
# 19             20                1       57  1.046994
# 20             21                1       57  2.027565
# 21             22                1       57  0.208635
# 22             23                1       57  0.949661
# 23             24                1       57  0.094143
# 24             25                1       57  0.465684
# 25             26                1       57  0.669894
# 26              1                2       57  2.101916
# 27              2                2       57  1.976430
# 28              3                2       57  1.013979
# 29              4                2       57  0.550145
# 30              5                2       57  3.311534
# 31              6                2       57  0.778199
# 32              7                2       57  4.772142
# 33              8                2       57  0.394131
# 34              9                2       57  1.249394
# 35             10                2       57  0.288177

# %%
list(theta_sql_df['theta'])
# Out:
# [2.4353127,
#  0.6799206,
#  0.056989934,
#  2.6667657,
#  0.05695637,
#  0.22326146,
#  1.4826194,
#  0.066789515,
#  1.0040221,
#  0.44573337,
#  0.32523856,
#  4.965209,
#  0.0073088836,
#  0.5265946,
#  0.5027867,
#  3.929241,
#  0.9191457,
#  0.90402764,
#  0.7953072,
#  1.0469936,
#  2.0275648,
#  0.20863518,
#  0.9496609,
#  0.09414342,
#  0.46568388,
#  0.669894,
#  2.101916,
#  1.9764304,
#  1.0139787,
#  0.550145,
#  3.3115344,
#  0.77819914,
#  4.7721415,
#  0.39413127,
#  1.2493935,
#  0.28817743]

# %% [markdown]
# ### Load data for validation (7 day) (normalized using percentile method)

# %%
#Load the processed and normalized  dataset 
import pickle
with open('MS_normalized_df.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
for i in range(len(data)):
    data.loc[i, 'Patient_ID'] = str(data.loc[i, 'Patient_ID'])

# %%
data['Gender'][::35][0:30]
# Out:
# 0       Female
# 35      Female
# 70        Male
# 105     Female
# 140     Female
# 175     Female
# 210     Female
# 245       Male
# 280     Female
# 315     Female
# 350     Female
# 385     Female
# 420       Male
# 455       Male
# 490       Male
# 525     Female
# 560     Female
# 595       Male
# 630     Female
# 665     Female
# 700     Female
# 735     Female
# 770     Female
# 805     Female
# 840     Female
# 875     Female
# 910       Male
# 945     Female
# 980     Female
# 1015      Male
# Name: Gender, dtype: object

# %%
data_p  = data[data["Patient_ID"] == "1005"]
data_p[data_p["Patient_Interval_Number"] >= 31]
# Out:
#     Patient_ID  Gender               Age Daytime_Interval  \
# 170       1005  Female  Between 30 to 60             Wake
# 171       1005  Female  Between 30 to 60          Morning
# 172       1005  Female  Between 30 to 60        Afternoon
# 173       1005  Female  Between 30 to 60          Evening
# 174       1005  Female  Between 30 to 60              Bed
#
#     Patient_Interval_Number Pain_Score Action_Pain Fatigue_Score  \
# 170                      31     Higher    Recorded        Normal
# 171                      32     Normal    Recorded         Lower
# 172                      33     Normal    Recorded        Normal
# 173                      34     Higher    Recorded        Normal
# 174                      35      Lower  Last State        Normal
#
#     Action_Fatigue Last_Activitybout_State Current_Activitybout_Action  \
# 170       Recorded                   Lower                      Higher
# 171       Recorded                  Higher                      Higher
# 172       Recorded                  Higher                      Higher
# 173       Recorded                  Higher                      Higher
# 174     Last State                  Higher                  Last State
#
#     EOD_PAW  Action_PAW
# 170    None        None
# 171    None        None
# 172    None        None
# 173    None    Recorded
# 174  Normal  Last State

# %%
data.dtypes
# Out:
# Patient_ID                     object
# Gender                         object
# Age                            object
# Daytime_Interval               object
# Patient_Interval_Number        object
# Pain_Score                     object
# Action_Pain                    object
# Fatigue_Score                  object
# Action_Fatigue                 object
# Last_Activitybout_State        object
# Current_Activitybout_Action    object
# EOD_PAW                        object
# Action_PAW                     object
# dtype: object

# %%
#Required Variables
people_states = {}   #people-states[Patient_No][state_no] #a dict containing lists of people, where every list contains a dictionary of all states regarding that people
people_actions = {} #a dict containing lists of people, where every list contains a dictionary of all actions regarding that people

#Patient list
Person_list = []   #total 8 ;1001-1008 patients , missing patient_id: 1017, 1021, 1051
for i in range(1001, 1111, 1):
    if(i== 1017 or i == 1021 or i == 1051):
        pass
    else:
        Person_list.append(str(i))

# %%
pd.options.mode.chained_assignment = None  # default='warn'
for person in Person_list:
    P = data[data['Patient_ID'] == person].reset_index()
    
    actual_states = []
    actual_actions = []
    for i in range(len(P)):
        #print(P.loc[i, 'Gender'])
        state = {}
        action = {}
        
        #Encode all actual states patients were in
        #state["Patient ID"] = person
        state["Gender"] = P.loc[i, "Gender"]
        state["Age"] = P.loc[i, "Age"]
        state["Current Daytime Interval"] = P.loc[i, "Daytime_Interval"]
        state["Current Interval Pain Score"] = P.loc[i, "Pain_Score"]
        state["Current Interval Fatigue Score"] = P.loc[i, "Fatigue_Score"]
        state["Last Interval Activity Bouts"] = P.loc[i, "Last_Activitybout_State"]
        state["EOD Positive Affect and Well-being"] = P.loc[i, "EOD_PAW"]
        actual_states.append(state)
        #Encode all actions performed by the patients
        if(P.loc[i, "Action_PAW"] == 'Last State'):
            print("Last state")
            continue
        else:
            action["Activitybouts"] = P.loc[i, "Current_Activitybout_Action"]
            action["Next Interval Assessment Pain"] = P.loc[i, "Action_Pain"]
            action["Next Interval Assessment Fatigue"] = P.loc[i, "Action_Fatigue"]
            #action["Next Interval Assessment Cognition"] = P.loc[i, "Action_Cognition"]
            #action["Next Interval Assessment Depression"] = P.loc[i, "Action_Depression"]
            #Action_Sleep_Efficiency
            #action["Next Interval Assessment Sleep Efficiency"] = P.loc[i, "Action_Sleep_Efficiency"]
            action["Next Interval Assessment PAW"] = P.loc[i, "Action_PAW"]
            actual_actions.append(action)
        
        
        
    people_states[person] = actual_states
    people_actions[person] = actual_actions
    #break
print("Finished")
# Out:
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Last state
# Finished

# %%
len(people_states["1001"])
# Out:
# 35

# %%
len(people_actions["1001"])
# Out:
# 34

# %%
#original states patients were in (7 days, 5 interval, 35 values for each patient): it is a dictionary where key is patient_id
people_states["1001"]
# Out:
# [{'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Wake',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Not Recorded',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Morning',
#   'Current Interval Pain Score': 'Lower',
#   'Current Interval Fatigue Score': 'Lower',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Afternoon',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Evening',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Bed',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': 'Normal'},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Wake',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Morning',
#   'Current Interval Pain Score': 'Lower',
#   'Current Interval Fatigue Score': 'Lower',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Afternoon',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Lower',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Evening',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Bed',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': 'Higher'},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Wake',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Morning',
#   'Current Interval Pain Score': 'Lower',
#   'Current Interval Fatigue Score': 'Lower',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Afternoon',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Evening',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Bed',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': 'Higher'},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Wake',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Morning',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Afternoon',
#   'Current Interval Pain Score': 'Lower',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Evening',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Bed',
#   'Current Interval Pain Score': 'Not Recorded',
#   'Current Interval Fatigue Score': 'Not Recorded',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': 'Higher'},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Wake',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Morning',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Lower',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Afternoon',
#   'Current Interval Pain Score': 'Lower',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Evening',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Bed',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': 'Normal'},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Wake',
#   'Current Interval Pain Score': 'Not Recorded',
#   'Current Interval Fatigue Score': 'Not Recorded',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Morning',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Lower',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Afternoon',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Evening',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Higher',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Bed',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Higher',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': 'Normal'},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Wake',
#   'Current Interval Pain Score': 'Not Recorded',
#   'Current Interval Fatigue Score': 'Not Recorded',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Morning',
#   'Current Interval Pain Score': 'Not Recorded',
#   'Current Interval Fatigue Score': 'Not Recorded',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Afternoon',
#   'Current Interval Pain Score': 'Higher',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Evening',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Lower',
#   'EOD Positive Affect and Well-being': None},
#  {'Gender': 'Female',
#   'Age': 'Between 30 to 60',
#   'Current Daytime Interval': 'Bed',
#   'Current Interval Pain Score': 'Normal',
#   'Current Interval Fatigue Score': 'Normal',
#   'Last Interval Activity Bouts': 'Normal',
#   'EOD Positive Affect and Well-being': 'Normal'}]

# %%
#original actions people perform (last state has no action to have a transition so action value for each patient is one
#less than the state value)
people_actions["1001"]
# Out:
# [{'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': 'Recorded'},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': 'Recorded'},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': 'Recorded'},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Not Recorded',
#   'Next Interval Assessment Fatigue': 'Not Recorded',
#   'Next Interval Assessment PAW': 'Recorded'},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': 'Recorded'},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Not Recorded',
#   'Next Interval Assessment Fatigue': 'Not Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Higher',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': 'Recorded'},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Not Recorded',
#   'Next Interval Assessment Fatigue': 'Not Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Not Recorded',
#   'Next Interval Assessment Fatigue': 'Not Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Lower',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': None},
#  {'Activitybouts': 'Normal',
#   'Next Interval Assessment Pain': 'Recorded',
#   'Next Interval Assessment Fatigue': 'Recorded',
#   'Next Interval Assessment PAW': 'Recorded'}]

# %% [markdown]
# ### Transform data into numpy format and save data

# %%
state_dict = states
action_dict = actions

# %%
for key, value in state_dict.items():
    print(key, value)
# Out:
# S1 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S2 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S3 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S4 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S5 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S6 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S7 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S8 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S9 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S10 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S11 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S12 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S13 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S14 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S15 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S16 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S17 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S18 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S19 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S20 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S21 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S22 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S23 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S24 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S25 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S26 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S27 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S28 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S29 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S30 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S31 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S32 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S33 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S34 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S35 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S36 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S37 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S38 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S39 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S40 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S41 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S42 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S43 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S44 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S45 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S46 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S47 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S48 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S49 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S50 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S51 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S52 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S53 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S54 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S55 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S56 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S57 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S58 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S59 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S60 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S61 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S62 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S63 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S64 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Wake', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S65 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S66 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S67 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S68 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S69 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S70 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S71 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S72 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S73 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S74 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S75 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S76 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S77 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S78 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S79 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S80 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S81 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S82 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S83 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S84 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S85 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S86 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S87 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S88 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S89 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S90 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S91 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S92 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S93 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S94 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S95 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S96 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S97 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S98 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S99 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S100 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S101 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S102 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S103 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S104 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S105 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S106 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S107 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S108 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S109 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S110 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S111 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S112 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S113 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S114 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S115 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S116 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S117 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S118 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S119 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S120 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S121 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S122 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S123 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S124 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S125 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S126 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S127 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S128 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Morning', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S129 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S130 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S131 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S132 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S133 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S134 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S135 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S136 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S137 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S138 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S139 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S140 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S141 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S142 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S143 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S144 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Lower', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S145 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S146 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S147 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S148 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S149 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S150 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S151 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S152 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S153 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S154 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S155 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S156 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S157 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S158 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S159 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S160 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Normal', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S161 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S162 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S163 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S164 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S165 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S166 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S167 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S168 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S169 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S170 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S171 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S172 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S173 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S174 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S175 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S176 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Higher', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S177 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S178 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# S179 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': None}
# S180 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': None}
# S181 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': None}
# S182 {'Gender': 'Male', 'Age': 'Younger than 30', 'Current Daytime Interval': 'Afternoon', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': None}
# ...
# S3014 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Normal'}
# S3015 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Higher'}
# S3016 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3017 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Lower'}
# S3018 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Normal'}
# S3019 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Higher'}
# S3020 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3021 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Lower'}
# S3022 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Normal'}
# S3023 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Higher'}
# S3024 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Lower', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3025 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Lower'}
# S3026 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Normal'}
# S3027 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Higher'}
# S3028 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3029 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Lower'}
# S3030 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Normal'}
# S3031 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Higher'}
# S3032 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3033 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Lower'}
# S3034 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Normal'}
# S3035 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Higher'}
# S3036 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3037 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Lower'}
# S3038 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Normal'}
# S3039 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Higher'}
# S3040 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Normal', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3041 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Lower'}
# S3042 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Normal'}
# S3043 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Higher'}
# S3044 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3045 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Lower'}
# S3046 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Normal'}
# S3047 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Higher'}
# S3048 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3049 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Lower'}
# S3050 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Normal'}
# S3051 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Higher'}
# S3052 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3053 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Lower'}
# S3054 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Normal'}
# S3055 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Higher'}
# S3056 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Higher', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3057 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Lower'}
# S3058 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Normal'}
# S3059 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Higher'}
# S3060 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Lower', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3061 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Lower'}
# S3062 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Normal'}
# S3063 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Higher'}
# S3064 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Normal', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3065 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Lower'}
# S3066 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Normal'}
# S3067 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Higher'}
# S3068 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Higher', 'EOD Positive Affect and Well-being': 'Not Recorded'}
# S3069 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Lower'}
# S3070 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Normal'}
# S3071 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Higher'}
# S3072 {'Gender': 'Female', 'Age': '60 and Older', 'Current Daytime Interval': 'Bed', 'Current Interval Pain Score': 'Not Recorded', 'Current Interval Fatigue Score': 'Not Recorded', 'Last Interval Activity Bouts': 'Not Recorded', 'EOD Positive Affect and Well-being': 'Not Recorded'}

# %%
# save behavior instances
behavior_instances = []
for key in people_states.keys():
    states = people_states[key]
    actions = people_actions[key]
    behavior_instance = []
    for i, state in enumerate(states):
        for key, value in state_dict.items():
            if state==value: state_code = int(key[1:])-1
        if i<len(actions):
            action = actions[i]
            for key, value in action_dict.items():
                if action==value: action_code = int(key[1:])-1
        else:
            action_code = -1
        behavior_instance.append([state_code, action_code])
    behavior_instances.append(behavior_instance)

# %%
np.save('behavior_instances.npy', behavior_instances)

# %%
# state visit frequency
state_vis_freq = []
for i in range(len(state_vis_freq_sql_df)):
    state_vis_freq.append(state_vis_freq_sql_df['expected_count'][i])

# %%
prob_action_given_state_sql_df
# Out:
#        policy_id  state_id state_code  action_id action_code   probability
# 0             37   3315187         S1       8973          A3  3.400253e-01
# 1             37   3315187         S1       8976          A6  1.034875e-03
# 2             37   3315187         S1       8979          A9  2.803656e-03
# 3             37   3315187         S1       8982         A12  8.369997e-06
# 4             37   3315187         S1       8985         A15  2.695903e-01
# ...          ...       ...        ...        ...         ...           ...
# 55291         37   3318258      S3072       9006         A36  4.588340e-06
# 55292         37   3318258      S3072       9009         A39  1.243086e-02
# 55293         37   3318258      S3072       9012         A42  5.941540e-05
# 55294         37   3318258      S3072       9015         A45  6.665999e-05
# 55295         37   3318258      S3072       9018         A48  3.156127e-07
#
# [55296 rows x 6 columns]

# %%
# probability of action given state
prob_action_given_state = np.zeros((len(state_dict), len(action_dict)))
for i in range(len(prob_action_given_state_sql_df)):
    state_code = prob_action_given_state_sql_df['state_code'][i]
    state_code = int(state_code[1:])-1
    action_code = prob_action_given_state_sql_df['action_code'][i]
    action_code = int(action_code[1:])-1
    prob_action_given_state[state_code,action_code] = prob_action_given_state_sql_df['probability'][i]
for i in range(prob_action_given_state.shape[0]):
    prob_action_given_state[i] /= prob_action_given_state[i].sum()

# %%
transition_proba_sql_df
# Out:
#         from_state_id from_state_code  action_id action_code  to_state_id  \
# 0             3315379            S193       8971          A1      3315443
# 1             3315379            S193       8971          A1      3315444
# 2             3315379            S193       8971          A1      3315445
# 3             3315379            S193       8971          A1      3315459
# 4             3315379            S193       8971          A1      3315460
# ...               ...             ...        ...         ...          ...
# 270331        3318254           S3068       9018         A48      3317810
# 270332        3318255           S3069       9018         A48      3317810
# 270333        3318256           S3070       9018         A48      3317810
# 270334        3318257           S3071       9018         A48      3317810
# 270335        3318258           S3072       9018         A48      3317810
#
#        to_state_code  probability
# 0               S257     0.020071
# 1               S258     0.012884
# 2               S259     0.014971
# 3               S273     0.063225
# 4               S274     0.040588
# ...              ...          ...
# 270331         S2624     1.000000
# 270332         S2624     1.000000
# 270333         S2624     1.000000
# 270334         S2624     1.000000
# 270335         S2624     1.000000
#
# [270336 rows x 7 columns]

# %%
# transition probability
transition_proba = np.zeros((len(state_dict), len(action_dict), len(state_dict)))
for i in range(len(transition_proba_sql_df)):
    from_state_code = transition_proba_sql_df['from_state_code'][i]
    from_state_code = int(from_state_code[1:])-1
    action_code = transition_proba_sql_df['action_code'][i]
    action_code = int(action_code[1:])-1
    to_state_code = transition_proba_sql_df['to_state_code'][i]
    to_state_code = int(to_state_code[1:])-1
    transition_proba[from_state_code,action_code,to_state_code] = transition_proba_sql_df['probability'][i]
for i in range(transition_proba.shape[0]):
    for j in range(transition_proba.shape[1]):
        if transition_proba[i,j].sum()!=0:
            transition_proba[i,j] /= transition_proba[i,j].sum()

# %%
np.save('state_vis_freq', state_vis_freq)
np.save('prob_action_given_state', prob_action_given_state)
np.save('transition_proba', transition_proba)

# %%
state_feature_name = list(theta_sql_df['feature_name'][:26])
action_feature_name = list(theta_sql_df['feature_name'][26:])
np.save('state_feature_name', list(theta_sql_df['feature_name'][:26]))
np.save('action_feature_name', list(theta_sql_df['feature_name'][26:]))

# %%
state_feature = np.zeros((len(state_dict), 26))
for state_code, state_detail in state_dict.items():
    state_code = int(state_code[1:]) - 1
    for key, value in state_detail.items():
        if value is None: value = 'None'
        for i in range(len(state_feature_name)):
            if key.lower()+':'+value.lower() == state_feature_name[i].lower():
                state_feature[state_code, i] = 1

# %%
action_feature = np.zeros((len(action_dict), 10))
for action_code, action_detail in action_dict.items():
    action_code = int(action_code[1:]) - 1
    for key, value in action_detail.items():
        if value is None: value = 'None'
        for i in range(len(action_feature_name)):
            if key.lower()+':'+value.lower() == action_feature_name[i].lower():
                action_feature[action_code, i] = 1

# %%
np.save('state_feature', state_feature)
np.save('action_feature', action_feature)

# %%
# initial state distribution
initial_state_dist = np.zeros(len(state_dict))
for behavior_instance in behavior_instances:
    initial_state_dist[behavior_instance[0][0]] += 1
initial_state_dist /= len(behavior_instances)

# %%
np.save('initial_state_dist', initial_state_dist)
